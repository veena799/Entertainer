# %%
import pandas as pd
import numpy as np

# %%
e=pd.read_excel('E:\\unified mentor projects\\Entertainer Data Anlytics\\Entertainer - Basic Info.xlsx')

# %%
e
# Out:
#         Entertainer Gender (traditional)  Birth Year
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# ..              ...                  ...         ...
# 65        Tom Hanks                    M        1956
# 66     Tony Bennett                    M        1926
# 67     Wayne Newton                    M        1942
# 68       Will Smith                    M        1968
# 69    Willie Nelson                    M        1933
#
# [70 rows x 3 columns]

# %%
b=pd.read_excel('E:\\unified mentor projects\\Entertainer Data Anlytics\\Entertainer - Breakthrough Info.xlsx')
b
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0             Adele                                          2008
# 1    Angelina Jolie                                          1999
# 2   Aretha Franklin                                          1967
# 3       Bette Davis                                          1934
# 4       Betty White                                          1952
# ..              ...                                           ...
# 65        Tom Hanks                                          1984
# 66     Tony Bennett                                          1951
# 67     Wayne Newton                                          1972
# 68       Will Smith                                          1990
# 69    Willie Nelson                                          1975
#
#                            Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                         19                           2009.0
# ...

# %%
data = pd.read_excel('E:\\unified mentor projects\\Entertainer Data Anlytics\\Last work.xlsx')
data
# Out:
#         Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0             Adele                                2016            NaN
# 1    Angelina Jolie                                2016            NaN
# 2   Aretha Franklin                                2014            NaN
# 3       Bette Davis                                1989         1989.0
# 4       Betty White                                2016            NaN
# ..              ...                                 ...            ...
# 65        Tom Hanks                                2016            NaN
# 66     Tony Bennett                                2016            NaN
# 67     Wayne Newton                                2016            NaN
# 68       Will Smith                                2016            NaN
# 69    Willie Nelson                                2016            NaN
#
# [70 rows x 3 columns]

# %%
e.isnull().sum()
# Out:
# Entertainer             0
# Gender (traditional)    0
# Birth Year              0
# dtype: int64

# %%
b.isnull().sum()
# Out:
# Entertainer                                     0
# Year of Breakthrough/#1 Hit/Award Nomination    0
# Breakthrough Name                               0
# Year of First Oscar/Grammy/Emmy                 6
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Entertainer                            0
# Year of Last Major Work (arguable)     0
# Year of Death                         40
# dtype: int64

# %%
d= pd.DataFrame(data)

# %%
d.dropna()
# Out:
#           Entertainer  Year of Last Major Work (arguable)  Year of Death
# 3         Bette Davis                                1989         1989.0
# 5         Bing Crosby                                1974         1977.0
# 6            Bob Hope                                1972         2003.0
# 8      Carole Lombard                                1942         1942.0
# 9       Carrie Fisher                                2016         2016.0
# 10         Cary Grant                                1966         1986.0
# 11    Charlie Chaplin                                1967         1977.0
# 12          Clara Bow                                1933         1965.0
# 13        Clark Gable                                1960         1960.0
# 15    Debbie Reynolds                                2006         2016.0
# 20        Ed Sullivan                                1973         1974.0
# 23      Elvis Presley                                1977         1977.0
# ...

# %%
d.shape
# Out:
# (70, 3)

# %%
b.dropna()
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0             Adele                                          2008
# 1    Angelina Jolie                                          1999
# 2   Aretha Franklin                                          1967
# 3       Bette Davis                                          1934
# 4       Betty White                                          1952
# ..              ...                                           ...
# 64    Stevie Wonder                                          1963
# 65        Tom Hanks                                          1984
# 66     Tony Bennett                                          1951
# 68       Will Smith                                          1990
# 69    Willie Nelson                                          1975
#
#                            Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                         19                           2009.0
# ...

# %%
d.dropna()
# Out:
#           Entertainer  Year of Last Major Work (arguable)  Year of Death
# 3         Bette Davis                                1989         1989.0
# 5         Bing Crosby                                1974         1977.0
# 6            Bob Hope                                1972         2003.0
# 8      Carole Lombard                                1942         1942.0
# 9       Carrie Fisher                                2016         2016.0
# 10         Cary Grant                                1966         1986.0
# 11    Charlie Chaplin                                1967         1977.0
# 12          Clara Bow                                1933         1965.0
# 13        Clark Gable                                1960         1960.0
# 15    Debbie Reynolds                                2006         2016.0
# 20        Ed Sullivan                                1973         1974.0
# 23      Elvis Presley                                1977         1977.0
# ...

# %%
result = pd.merge(e,d,on='Entertainer',how='inner')

# %%
result
# Out:
#         Entertainer Gender (traditional)  Birth Year  \
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# ..              ...                  ...         ...
# 65        Tom Hanks                    M        1956
# 66     Tony Bennett                    M        1926
# 67     Wayne Newton                    M        1942
# 68       Will Smith                    M        1968
# 69    Willie Nelson                    M        1933
#
#     Year of Last Major Work (arguable)  Year of Death
# 0                                 2016            NaN
# 1                                 2016            NaN
# 2                                 2014            NaN
# 3                                 1989         1989.0
# ...

# %%
result1 = pd.merge(b,result,on='Entertainer',how='inner')
result1
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0             Adele                                          2008
# 1    Angelina Jolie                                          1999
# 2   Aretha Franklin                                          1967
# 3       Bette Davis                                          1934
# 4       Betty White                                          1952
# ..              ...                                           ...
# 65        Tom Hanks                                          1984
# 66     Tony Bennett                                          1951
# 67     Wayne Newton                                          1972
# 68       Will Smith                                          1990
# 69    Willie Nelson                                          1975
#
#                            Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                         19                           2009.0
# ...

# %%
result1.isnull().sum()
# Out:
# Entertainer                                      0
# Year of Breakthrough/#1 Hit/Award Nomination     0
# Breakthrough Name                                0
# Year of First Oscar/Grammy/Emmy                  6
# Gender (traditional)                             0
# Birth Year                                       0
# Year of Last Major Work (arguable)               0
# Year of Death                                   40
# dtype: int64

# %%
r1 = result1.dropna()

# %%
r1.shape
# Out:
# (26, 8)

# %%
r1.head(5)
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 3       Bette Davis                                          1934
# 5       Bing Crosby                                          1931
# 6          Bob Hope                                          1938
# 10       Cary Grant                                          1933
# 11  Charlie Chaplin                                          1915
#
#                    Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 3                   Of Human Bondage                           1935.0
# 5                      Several Songs                           1962.0
# 6          The Big Broadcast of 1938                           1940.0
# 10  She Done Him Wrong, I'm No Angel                           1970.0
# 11                         The Tramp                           1929.0
#
#    Gender (traditional)  Birth Year  Year of Last Major Work (arguable)  \
# ...

# %% [markdown]
# # Data Visulaization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x='Year of Last Major Work (arguable)',y='Entertainer',data=r1)
# Out:
# <Axes: xlabel='Year of Last Major Work (arguable)', ylabel='Entertainer'>

# %%
r1['Gender (traditional)'].value_counts().plot.pie(autopct= '%1.1f%%')
plt.title('Gender percentage')
# Out:
# Text(0.5, 1.0, 'Gender percentage')

# %%
r1['Year of First Oscar/Grammy/Emmy'].value_counts().plot.pie(autopct= '%1.1f%%')
# Out:
# <Axes: ylabel='Year of First Oscar/Grammy/Emmy'>

# %%
plt.scatter(x='Year of First Oscar/Grammy/Emmy',y='Entertainer',data=r1)

# %%
r1.head(5)
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 3       Bette Davis                                          1934
# 5       Bing Crosby                                          1931
# 6          Bob Hope                                          1938
# 10       Cary Grant                                          1933
# 11  Charlie Chaplin                                          1915
#
#                    Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 3                   Of Human Bondage                           1935.0
# 5                      Several Songs                           1962.0
# 6          The Big Broadcast of 1938                           1940.0
# 10  She Done Him Wrong, I'm No Angel                           1970.0
# 11                         The Tramp                           1929.0
#
#    Gender (traditional)  Birth Year  Year of Last Major Work (arguable)  \
# ...

# %%
sns.histplot(x='Year of First Oscar/Grammy/Emmy',y='Entertainer',data=r1)
# Out:
# <Axes: xlabel='Year of First Oscar/Grammy/Emmy', ylabel='Entertainer'>

# %%
import seaborn as sns
sns.boxplot(x='Year of Breakthrough/#1 Hit/Award Nomination', y='Year of Last Major Work (arguable)', data=r1)
# Out:
# <Axes: xlabel='Year of Breakthrough/#1 Hit/Award Nomination', ylabel='Year of Last Major Work (arguable)'>
